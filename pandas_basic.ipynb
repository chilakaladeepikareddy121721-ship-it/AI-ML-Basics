# %% [markdown]
# * What is pandas
# * Why pandas
# * Series
# * DataFrame
# * Exploring data
# * Selection data
# * Sorting data
# * Aggregating data
# * Applying Functions

# %% [markdown]
# # what is pandas?/
# * panda is the python powerful library  use for data manipulation

# %% [markdown]
# # Why panda?/
# *

# %% [markdown]
# # Series = 1d , 2d

# %%
import pandas as pd
import numpy  as np

# %%
arr_1d = np.array([1,2,3,4,55])
print(type(arr_1d))
arr_1d
# Out:
# <class 'numpy.ndarray'>
# array([ 1,  2,  3,  4, 55])

# %%
data = [10,20,30,40,50,60,70]

# %%
lab = ['d','e','e','p','i','k','a']

# %%
d = pd.Series(data, index=lab)
print(d)
# Out:
# d    10
# e    20
# e    30
# p    40
# i    50
# k    60
# a    70
# dtype: int64

# %%
var_1 = [1,2,3,4]
sr_1 = pd.Series(var_1,index=[11,22,33,44])
print(sr_1)
# Out:
# 11    1
# 22    2
# 33    3
# 44    4
# dtype: int64

# %%
data1 = [[10,20,30],[10,203,2]]
df_1 = pd.Series(data1)
print(type(df_1))
df_1
# Out:
# <class 'pandas.core.series.Series'>
# 0    [10, 20, 30]
# 1    [10, 203, 2]
# dtype: object

# %% [markdown]
# # Data Frame

# %%
data2 = [[10,20,30,40],[101,202,303,404]]
df_2 = pd.DataFrame(data2)
print(type(df_2))
df_2
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      0    1    2    3
# 0   10   20   30   40
# 1  101  202  303  404

# %%
df_2 = pd.DataFrame(data2,columns = ['A','B','C','D'],index=['a','b'])
df_2
# Out:
#      A    B    C    D
# a   10   20   30   40
# b  101  202  303  404

# %%
data = [('chilakala',90),('deepika',80),('Reddy',70)]
d = pd.DataFrame(data,columns=['Name','Age'])
d
# Out:
#         Name  Age
# 0  chilakala   90
# 1    deepika   80
# 2      Reddy   70

# %%
data3 ={
    'roll': [10,20,30,40,50],
    'name': ['deepu','bharadwaj','sunny','kumesh','kiran']
}

# %%
d = pd.DataFrame(data3)
d
# Out:
#    roll       name
# 0    10      deepu
# 1    20  bharadwaj
# 2    30      sunny
# 3    40     kumesh
# 4    50      kiran

# %% [markdown]
# # List of List

# %%
import pandas as dp
a = [['deepika',20],['reddy',90],['chilakala',50]]
data1 = dp.DataFrame(a,columns=['name','numnber'])
print(data1)
# Out:
#         name  numnber
# 0    deepika       20
# 1      reddy       90
# 2  chilakala       50

# %%
d1 = np.array([1,2,3,4])
d2 = np.array([10,20,30,40])
data_fr = {
    'df1':d1,
    'df2':d2
}
print(data_fr)
# Out:
# {'df1': array([1, 2, 3, 4]), 'df2': array([10, 20, 30, 40])}

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba65f283-7275-4357-a807-f87cdab756d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba65f283-7275-4357-a807-f87cdab756d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/IPL_Matches_2008_2022.csv')

# %%
df.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
df.tail(10)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 940  335991  Chandigarh  2008-04-25  2007/08          10
# 941  335990   Hyderabad  2008-04-24  2007/08           9
# 942  335989     Chennai  2008-04-23  2007/08           8
# 943  335988   Hyderabad  2008-04-22  2007/08           7
# 944  335987      Jaipur  2008-04-21  2007/08           6
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 940              Kings XI Punjab               Mumbai Indians
# 941              Deccan Chargers             Rajasthan Royals
# 942          Chennai Super Kings               Mumbai Indians
# 943              Deccan Chargers             Delhi Daredevils
# ...

# %% [markdown]
# # Exploring Data

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.head(6)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
# 5  1304115     Mumbai  2022-05-21   2022           69
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
# 5               Delhi Capitals        Mumbai Indians
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# ...

# %%
df.tail(6)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 944  335987      Jaipur  2008-04-21  2007/08           6
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 944             Rajasthan Royals              Kings XI Punjab
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# ...

# %%
df.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.isna()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
df.isna().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.dropna()
# Out:
#           ID           City        Date   Season MatchNumber  \
# 282  1136592          Delhi  2018-05-02     2018          32
# 296  1136578        Kolkata  2018-04-21     2018          18
# 308  1136566         Jaipur  2018-04-11     2018           6
# 316  1082648      Bangalore  2017-05-17     2017  Eliminator
# 383   980999      Bangalore  2016-05-18     2016          50
# 384   980997  Visakhapatnam  2016-05-17     2016          49
# 389   980989        Kolkata  2016-05-14     2016          45
# 411   980943      Hyderabad  2016-04-26     2016          22
# 441   829807      Hyderabad  2015-05-15     2015          52
# 472   829743  Visakhapatnam  2015-04-22     2015          19
# 520   733993          Delhi  2014-05-10     2014          32
# 717   501255      Bangalore  2011-05-14     2011          58
# 728   501245        Kolkata  2011-05-07     2011          48
# 757   501215          Kochi  2011-04-18     2011          18
# ...

# %%
df.fillna(0)
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
df.isnull(

).sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(1012)

# %%
df.dropna(inplace = True)

# %% [markdown]
# # Selecting Data

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df['Season']
# Out:
# 282       2018
# 296       2018
# 308       2018
# 316       2017
# 383       2016
# 384       2016
# 389       2016
# 411       2016
# 441       2015
# 472       2015
# 520       2014
# 717       2011
# 728       2011
# 757       2011
# 860       2009
# 886       2009
# 889       2009
# 908    2007/08
# 910    2007/08
# Name: Season, dtype: object

# %%
(df[['Season','method']])
# Out:
#       Season method
# 282     2018    D/L
# 296     2018    D/L
# 308     2018    D/L
# 316     2017    D/L
# 383     2016    D/L
# 384     2016    D/L
# 389     2016    D/L
# 411     2016    D/L
# 441     2015    D/L
# 472     2015    D/L
# 520     2014    D/L
# 717     2011    D/L
# 728     2011    D/L
# 757     2011    D/L
# 860     2009    D/L
# 886     2009    D/L
# 889     2009    D/L
# 908  2007/08    D/L
# 910  2007/08    D/L

# %%
new_df = df[['Season','method']]
print(new_df)
# Out:
#       Season method
# 282     2018    D/L
# 296     2018    D/L
# 308     2018    D/L
# 316     2017    D/L
# 383     2016    D/L
# 384     2016    D/L
# 389     2016    D/L
# 411     2016    D/L
# 441     2015    D/L
# 472     2015    D/L
# 520     2014    D/L
# 717     2011    D/L
# 728     2011    D/L
# 757     2011    D/L
# 860     2009    D/L
# 886     2009    D/L
# 889     2009    D/L
# 908  2007/08    D/L
# 910  2007/08    D/L
